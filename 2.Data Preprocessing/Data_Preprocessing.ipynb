# %% [markdown]
# # 2. Data Preprocessing

# %%
import pandas as pd

# %%
dataset=pd.read_csv("dataset_phishing.csv")

# %%
dataset.isnull().sum()
# Out:
# url                0
# length_url         0
# length_hostname    0
# ip                 0
# nb_dots            0
#                   ..
# web_traffic        0
# dns_record         0
# google_index       0
# page_rank          0
# status             0
# Length: 89, dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
dataset.drop("url",axis=1,inplace=True)

# %%
dataset.shape
# Out:
# (11430, 88)

# %%
dataset["status"].value_counts()
# Out:
# status
# legitimate    5715
# phishing      5715
# Name: count, dtype: int64

# %%
dataset["status"]=dataset["status"].map({"legitimate":0,"phishing":1})

# %%
dataset["status"].value_counts()
# Out:
# status
# 0    5715
# 1    5715
# Name: count, dtype: int64

# %%
dataset.to_csv("phishing_preprocessed.csv",index=False)

# %%
dataset.head()
# Out:
#    length_url  length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  \
# 0          37               19   0        3           0      0      0       0
# 1          77               23   1        1           0      0      0       0
# 2         126               50   1        4           1      0      1       2
# 3          18               11   0        2           0      0      0       0
# 4          55               15   0        2           2      0      0       0
#
#    nb_or  nb_eq  ...  domain_in_title  domain_with_copyright  \
# 0      0      0  ...                0                      1
# 1      0      0  ...                1                      0
# 2      0      3  ...                1                      0
# 3      0      0  ...                1                      0
# 4      0      0  ...                0                      1
#
#    whois_registered_domain  domain_registration_length  domain_age  \
# 0                        0                          45          -1
# 1                        0                          77        5767
# 2                        0                          14        4004
# 3                        0                          62          -1
# 4                        0                         224        8175
#
#    web_traffic  dns_record  google_index  page_rank  status
# 0            0           1             1          4       0
# 1            0           0             1          2       1
# 2      5828815           0             1          0       1
# 3       107721           0             0          3       0
# 4         8725           0             0          6       0
#
# [5 rows x 88 columns]
